# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Diwali = pd.read_csv('C:/Users/aksha/OneDrive/Desktop/ITPRENEUR/Diwali_Sales_Data.csv', encoding='ISO-8859-1')

# %%
Diwali
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
Diwali.shape
# Out:
# (11251, 15)

# %%
Diwali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# # Drop unrelated / blank Columns

# %%
Diwali.drop(['Status','unnamed1'], axis=1 , inplace=True)

# %% [markdown]
# # Check For Null Values

# %%
pd.isnull(Diwali).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# # Drop Null Values

# %%
Diwali.dropna(inplace=True)

# %% [markdown]
# # Change Data Type

# %%
Diwali['Amount'] = Diwali['Amount'].astype('int')

# %%
Diwali['Amount'].dtypes
# Out:
# dtype('int64')

# %%
Diwali.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
Diwali.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# # Use describe() for specific columns

# %%
Diwali[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Gender

# %% [markdown]
# # Plotting a bar chart for Gender and it's count

# %%
ax = sns.countplot(x = 'Gender',data = Diwali,palette=['blue','orange'])

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_3672\3985840535.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x = 'Gender',data = Diwali,palette=['blue','orange'])

# %% [markdown]
# # Plotting a bar chart for gender vs total amount

# %%
Sales_Gender = Diwali.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(data = Sales_Gender ,x = 'Gender',y= 'Amount' , palette = ['blue','orange'])
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_3672\3885812693.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = Sales_Gender ,x = 'Gender',y= 'Amount' , palette = ['blue','orange'])
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men.

# %% [markdown]
# # Age

# %%
ax = sns.countplot(data=Diwali,x='Age Group',hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Total Amount vs Age Group

# %%
Sales_Age = Diwali.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
Age_Group_Color = ['blue','orange','green','red','yellow','brown','purple']
sns.barplot(data = Sales_Age,x = 'Age Group',y= 'Amount',palette=Age_Group_Color)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_3672\2430900172.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = Sales_Age,x = 'Age Group',y= 'Amount',palette=Age_Group_Color)
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the buyers are of age group between 26-35 yrs female

# %% [markdown]
# # States

# %% [markdown]
# # Total number of orders from top 10 states

# %%
Sales_States = Diwali.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
States_Color = ['blue','orange','green','red','yellow','brown','purple','hotpink','grey','black']
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(data=Sales_States,x='State',y='Orders',palette=States_Color)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_3672\1352110063.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=Sales_States,x='State',y='Orders',palette=States_Color)
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# # Total Amount / Sales from top 10 States

# %%
Sales_States = Diwali.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
States_Color = ['blue','orange','green','red','yellow','brown','purple','hotpink','grey','black']
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(data=Sales_States,x='State',y='Amount',palette=States_Color)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_3672\3157704435.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=Sales_States,x='State',y='Amount',palette=States_Color)
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# # Marital Status

# %%
ax = sns.countplot(data=Diwali,x='Marital_Status',palette=['blue','orange'])

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_3672\1591883053.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=Diwali,x='Marital_Status',palette=['blue','orange'])

# %%
Sales_State = Diwali.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(data=Sales_State,x='Marital_Status',y='Amount',hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %% [markdown]
# # Occupation

# %%
ax = sns.countplot(data = Diwali, x = 'Occupation',hue='Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
Sales_State = Diwali.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(data=Sales_State,x='Occupation',y='Amount',hue='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector

# %% [markdown]
# # Product Category

# %%
ax = sns.countplot(data=Diwali,x='Product_Category',hue='Product_Category')
sns.set(rc={'figure.figsize':(20,10)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
Sales_State = Diwali.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)

sns.barplot(data=Sales_State,x='Product_Category',y='Amount',hue='Product_Category')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category

# %%
Sales_State = Diwali.groupby(['Product_ID'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)

sns.barplot(data=Sales_State,x='Product_ID',y='Orders',hue='Product_ID')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# # Top 10 most sold products (same thing as above)

# %%
Diwali.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# # Conclusion:

# %% [markdown]
# # Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category
